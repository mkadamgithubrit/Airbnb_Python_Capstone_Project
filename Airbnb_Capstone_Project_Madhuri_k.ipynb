# %% [markdown]
# <a href="https://colab.research.google.com/github/mkadamgithubrit/Airbnb_Python_Capstone_Project/blob/main/Airbnb_Capstone_Project_Madhuri_k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Airbnb_Logo_Bélo.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - madhuri kadam

# %% [markdown]
# #**What is Airbnb?**
# #Airbnb, Inc. is an American san francisco company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities.

# %% [markdown]
# #**SUMMERY**
#
#  **It was founded in 2008 and has since become one of the most popular and successful sharing economy companies in the world. Airbnb's platform allows hosts to create listings for their properties, including photos, descriptions, and pricing.**
#  **Airbnb is an online platform that allows people to rent out their homes, apartments, or other types of properties to travelers looking for short-term accommodation.**
#
# **Hosts can create profiles, list their properties, set prices, and communicate with guests through the platform. Airbnb charges hosts a commission on each booking, while guests pay a service fee that varies depending on the price of the reservation.**
#
# **Airbnb offers a variety of lodging options, ranging from budget-friendly shared rooms to high-end luxury villas. Users can search for properties based on location, price, amenities, and other criteria, and can book reservations directly through the website or mobile app.**
#
# **As of 2021 Airbnb operaters in more than 220 countries abn regions, with over 4 miliion active listings on the platform. the company has revolutionized the travel industry and has become a mejor player in the sharing economy**
#
# **This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.**

# %% [markdown]
# #Dataset Description
#
# ####**Id** - Unique Id
# ####**Name** - Name of Listing
# ####**host_id** - Unique host id
# ####**host_name** -Name of the host
# ####**neighbourhood_group** - neighbourhood_group
# ####**neighbourhood** - neighbourhood
# ####**latitude** - Latitude range
# ####**longitude** - Longitude range
# ####**room_type** - Type of Listing
# ####**price** - Price of listing
# ####**minimum_nights** - Minimum nights to be paid for
# ####**Number_of reviews** - Number of reviews
# ####**last_review** - Content of the last reviews
# ####**review_per month** - Number of check per month
# ####**calculated_host_listing_count** - Total count
# ####**availability_365** - Availability around the year

# %% [markdown]
# #**Problem Statement:**
#
# ###In this project, the goal is to analyze the Airbnb dataset using Python to identify the key factors that contribute to the popularity of listings. By exploring features such as location, property type, amenities, reviews, and pricing, the project aims to gain insights into the characteristics that make certain listings more popular than others. The challenge lies in effectively preprocessing the data, conducting relevant statistical analysis, and creating data visualizations to present the findings in a clear and actionable manner. The ultimate objective is to help hosts and property managers optimize their listings to attract more guests and enhance overall booking success.

# %% [markdown]
# #**Exploratory Data Analysis**
#
#
# ###Exploratory Data Analysis (EDA) is the process of visually and statistically examining a dataset to gain insights into its structure, patterns, and relationships between variables. EDA involves summarizing main characteristics of the data, uncovering hidden patterns, identifying outliers, and preparing the data for modeling.

# %% [markdown]
# ###**Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###**Dataset loading**

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
airbnb_data = '/content/drive/MyDrive/almabetter/EDA-- Hotel Booking/Airbnb NYC 2019.csv'
df = pd.read_csv(airbnb_data)

# %% [markdown]
# ###**Dataset First View**

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Null values count
df.isnull().sum().reset_index().rename(columns={'index':'columns',0:'null_value'})
# Out:
#                            columns  null_value
# 0                               id           0
# 1                             name          16
# 2                          host_id           0
# 3                        host_name          21
# 4              neighbourhood_group           0
# 5                    neighbourhood           0
# 6                         latitude           0
# 7                        longitude           0
# 8                        room_type           0
# 9                            price           0
# 10                  minimum_nights           0
# 11               number_of_reviews           0
# 12                     last_review       10052
# 13               reviews_per_month       10052
# 14  calculated_host_listings_count           0
# 15                availability_365           0

# %%
# top 5 row
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# summerising data
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Uderstanding the data by heading
df.columns
pd.DataFrame(df.columns)
# Out:
#                                  0
# 0                               id
# 1                             name
# 2                          host_id
# 3                        host_name
# 4              neighbourhood_group
# 5                    neighbourhood
# 6                         latitude
# 7                        longitude
# 8                        room_type
# 9                            price
# 10                  minimum_nights
# 11               number_of_reviews
# 12                     last_review
# 13               reviews_per_month
# 14  calculated_host_listings_count
# 15                availability_365

# %%
# row and columns in the dataframe
df.index,df.shape
# Out:
# (RangeIndex(start=0, stop=48895, step=1), (48895, 16))

# %%
# drop the  maximum null value present in columns
df.drop(['id','last_review'],axis=1,inplace=True)

# %% [markdown]
# This is basic information and basic exploration for the data set

# %% [markdown]
# ####**We are renaming some columns to ease the understanding of the dataset.**

# %%
# renaming some column name for better understanding
df1 = df.rename(columns= {'neighbourhood_group': 'Location', 'neighbourhood': 'Area'},inplace=False) # inplace parameter is used to make chenge inplace true return with chenges and False return without chenges
df1
# Out:
#                                                     name   host_id  \
# 0                     Clean & quiet apt home by the park      2787
# 1                                  Skylit Midtown Castle      2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3                        Cozy Entire Floor of Brownstone      4869
# 4       Entire Apt: Spacious Studio/Loft by central park      7192
# ...                                                  ...       ...
# 48890    Charming one bedroom - newly renovated rowhouse   8232441
# 48891      Affordable room in Bushwick/East Williamsburg   6570630
# 48892            Sunny Studio at Historical Neighborhood  23492952
# 48893               43rd St. Time Square-cozy single bed  30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name   Location                Area  latitude  longitude  \
# 0               John   Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# # **Data Analysis on Airbnb Dataset**

# %% [markdown]
# ##Q.1 What can we learn about different hosts and areas?

# %%
# Distribution of Hosts and Listings
host_count = df['host_id'].nunique()
listing_count = df.shape[0]
# The top 10 popular neighborhoods based on the number of listings.
top_hosts = df.groupby(['host_name'])['calculated_host_listings_count'].max().reset_index()
top_hosts.sort_values(by='calculated_host_listings_count', ascending=False).head(10)
# Out:
#               host_name  calculated_host_listings_count
# 9781       Sonder (NYC)                             327
# 1356         Blueground                             232
# 5336               Kara                             121
# 5471             Kazuya                             103
# 9780             Sonder                              96
# 4809     Jeremy & Laura                              96
# 2123  Corporate Housing                              91
# 5524                Ken                              87
# 8395            Pranjal                              65
# 7223               Mike                              52

# %% [markdown]
# #### the top 10 hosts with the highest number of listings, making it easy to identify the most active hosts in the dataset.

# %% [markdown]
# ##Q.2 Correlation Heatmap

# %%
numeric_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
correlation_matrix = df[numeric_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Pastel1', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ####The heatmap presents a color-coded representation of the correlation coefficients, with warmer colors indicating positive correlations and cooler colors representing negative correlations.

# %% [markdown]
# ##Q.3 Display the top property types with the highest number of listings

# %%
# Group the data by 'room_type' and calculate the total number of listings for each room type
property_bookings = df.groupby('room_type')['calculated_host_listings_count'].sum().reset_index()

# Sort the data by total number of listings in descending order
property_bookings = property_bookings.sort_values(by='calculated_host_listings_count', ascending=False)

# Display the top  property types with the highest number of listings
top_property_types = property_bookings.head(5)

# Create a bar plot to visualize the top property types with the highest number of listings
plt.figure(figsize=(10, 6))
plt.bar(top_property_types['room_type'], top_property_types['calculated_host_listings_count'], color='pink')
plt.title('Top Property Types with the Highest Number of Listings')
plt.xlabel('Room Type')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ####we analyzed the data to identify the top property types with the highest number of listings. The results show that [room type 1] and [room type 2] are the most popular choices among hosts.

# %% [markdown]
# ##Q.4 Which are the different neighborhood groups present in the dataset, and what percentage of the data does each group represent?

# %%
# Group the data by 'neighbourhood_group' and count the occurrences
group_counts = df['neighbourhood_group'].value_counts()

# Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(group_counts, labels=group_counts.index, autopct='%1.1f%%', startangle=140, shadow=True)
plt.title('Distribution of Data by Neighbourhood Group')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ####The pie chart illustrates the distribution of data across different neighborhood groups. It provides an overview of the relative prevalence of each group, helping identify the dominant neighborhoods and their representation in the dataset.

# %% [markdown]
# ##Q.5 How does the price distribution of Airbnb listings vary based on different room types and across various neighborhood groups (e.g., boroughs, districts)?

# %%
# creat the bar chart
sns.barplot(data=df, x="room_type", y="price", hue="neighbourhood_group")
plt.title('Price Distribution by Room Type and Neighbourhood Group')
plt.xlabel('Room Type')
plt.ylabel('Price')

plt.show()

# %% [markdown]
# ####In this visualization, we can observe how prices vary across room types and how different neighborhood groups influence the price distribution for each room type.

# %% [markdown]
# ##Q.6 Creates a box plot for variables to visualize their distributions and identify outliers

# %%
# Selecting the numerical columns for the box plot
numerical_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# Creating the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numerical_columns])
plt.title('Box Plot of Numerical Variables')
plt.ylabel('Values')
plt.xticks(rotation=15, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# ####The output will be a single box plot with boxes representing the interquartile range (IQR), whiskers extending to data points within a certain range, and any individual points beyond the whiskers considered outliers for each of the selected numerical columns. The x-axis will display the column names, and the y-axis will represent the values of these numerical variables.

# %% [markdown]
# ##Q.7 How do the prices differ among different room types (e.g., entire homes, private rooms, shared rooms)?

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='room_type', y='price', palette='Set2')
plt.title('Average Price by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# #### a bar plot with the x-axis representing the different room types ('room_type'), the y-axis representing the average price ('price'), and bars of different heights for each room type. basical The code creates a bar plot to display the average price for each room type in the dataset

# %% [markdown]
# ##Q.8 Which hosts are the busiest and why?

# %%
busy_hosts = df.groupby(['host_name','host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts = busy_hosts.sort_values(by='number_of_reviews', ascending=False).head(10)
busiest_hosts
# Out:
#       host_name   host_id        room_type  number_of_reviews
# 10279      Dona  47621202     Private room                629
# 17708        Jj   4734398     Private room                607
# 25566      Maya  37312959     Private room                543
# 6235      Carol   2369681     Private room                540
# 8947   Danielle  26432133     Private room                510
# 3950        Asa  12949460  Entire home/apt                488
# 37748     Wanda    792159     Private room                480
# 22499     Linda   2680820     Private room                474
# 8625       Dani     42273  Entire home/apt                467
# 2942     Angela  23591164     Private room                466

# %%
name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(name, reviews, color ='skyblue',
        width = 0.4)

plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title("Busiest Hosts")
plt.show()

# %% [markdown]
# ####The code creates a bar plot using Matplotlib, where the x-axis represents the "Name of the Host" and the y-axis represents the "Number of Reviews." It visualizes the busiest hosts and their corresponding review counts, helping to identify which hosts have received the most reviews.

# %% [markdown]
# ##Q.9 Top 5 areas with most number of bookings.

# %%
# Group by 'neighbourhood_group' and calculate the number of bookings for each group
top_neighbourhood_groups = df['neighbourhood_group'].value_counts().nlargest(5).index.tolist()

# Filter the DataFrame to include data for the top 5 neighbourhood groups
top_neighbourhood_groups_data = df[df['neighbourhood_group'].isin(top_neighbourhood_groups)]

# Create the scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(data=top_neighbourhood_groups_data, x='longitude', y='latitude', hue='neighbourhood_group', palette='Set1', s=80)
plt.title('Top 5 Neighbourhood Groups with Most Number of Bookings (Scatter Plot)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Neighbourhood Group', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ###Groups the data by 'neighbourhood_group' and calculates the number of bookings for each group, selecting the top 5 groups with the most bookings.Filters the DataFrame to include data only for the top 5 neighbourhood groups.

# %% [markdown]
# ##Q.10 top 10 areas with most numbers of visitors.

# %%
# Group the data by 'neighbourhood_group' and 'neighbourhood' and count the occurrences
visitors_count_by_area = df.groupby(['neighbourhood_group', 'neighbourhood']).size().reset_index(name='count')

# Sort the data by the number of visitors in descending order
top_10_areas = visitors_count_by_area.sort_values(by='count', ascending=False).head(10)

# Bar chart to visualize the top 10 areas with the most number of visitors by neighbourhood_group
plt.figure(figsize=(8, 6))
plt.bar(top_10_areas['neighbourhood_group'] + ': ' + top_10_areas['neighbourhood'], top_10_areas['count'])
plt.xlabel('Neighborhood Group: Neighborhood')
plt.ylabel('Number of Visitors')
plt.title('Top 10 Areas with the Most Number of Visitors by Neighbourhood Group')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### the top 10 areas with the most visitors, grouped by neighborhood groups. Each bar represents a neighborhood within a neighborhood group, and its height corresponds to the "Number of Visitors." The x-axis labels are formatted as "Neighborhood Group: Neighborhood," and the chart is titled "Top 10 Areas with the Most Number of Visitors by Neighbourhood Group.

# %% [markdown]
# #Conclusion

# %% [markdown]
# ## So far, My purpose is to  by providing information and answering a wide range of questions. I have done some basic exploring of the dataset and have gain few insights from it such as:
#
# ### The code calculates the number of unique hosts and total listings in the dataset. It also lists the top 10 hosts with the highest number of listings managed.
#
# ### The code creates a heatmap to visualize the correlation between selected numerical columns in the dataset. It provides insight into how these variables are related to each other, with values annotated on the heatmap.
#
# ### The code groups the data by 'room_type,' calculates the total number of listings for each room type, and then displays the top 5 property types with the highest number of listings in a bar plot.
#
# ### groups the data by 'neighbourhood_group,' counts the occurrences, and then creates a pie chart to visualize the distribution of data by neighbourhood group.
#
# ### a bar chart displaying the price distribution by room type and neighbourhood group.
#
# ### It helps identify outliers and provides an overview of the central tendency and spread of the data.
#
# ### It provides a visual comparison of average prices among room types.
# ###This code creates a bar plot showing the number of reviews for the busiest hosts. It helps identify hosts with the highest review counts.
# ###groups the data by 'neighbourhood_group' and 'neighbourhood,' counts the occurrences, and then visualizes the top 10 areas with the most visitors by creating a bar chart.

# %% [markdown]
# #**---------------------------------------- The End---------------------------------------**
